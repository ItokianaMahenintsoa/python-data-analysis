# %% [markdown]
# <a href="https://colab.research.google.com/github/ItokianaMahenintsoa/python-data-analysis/blob/main/Python_Data_Analysis_Started_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
obj = pd.Series([4, 7 -5, 3])
obj
# Out:
# 0    4
# 1    2
# 2    3
# dtype: int64

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [np.int64(4), np.int64(2), np.int64(3)]
# Length: 3, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2["a"]
# Out:
# np.int64(-5)

# %%
obj2["d"] = 6
obj2[["c", "a", "d"]]
# Out:
# c    3
# a   -5
# d    6
# dtype: int64

# %%
obj2[obj2 > 0]
# Out:
# d    6
# b    7
# c    3
# dtype: int64

# %%
obj2 * 2
# Out:
# d    12
# b    14
# a   -10
# c     6
# dtype: int64

# %%
import numpy as np

# %%
np.exp(obj2)
# Out:
# d     403.428793
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
"b" in obj2
# Out:
# True

# %%
"e" in obj2
# Out:
# False

# %%
sdata = {"Ohio": 35000, "Texas":71000, "Oregan":1600, "Utah":5000}

# %%
obj3 = pd.Series(sdata)

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregan     1600
# Utah       5000
# dtype: int64

# %%
obj3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregan': 1600, 'Utah': 5000}

# %%
states = ["California", "Ohio", "Oregan", "Texas"]

# %%
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregan         1600.0
# Texas         71000.0
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregan        False
# Texas         False
# dtype: bool

# %%
pd.notna(obj4)
# Out:
# California    False
# Ohio           True
# Oregan         True
# Texas          True
# dtype: bool

# %%
obj4.isna()
# Out:
# California     True
# Ohio          False
# Oregan        False
# Texas         False
# dtype: bool

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregan     1600
# Utah       5000
# dtype: int64

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregan         1600.0
# Texas         71000.0
# dtype: float64

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregan          3200.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
obj4.name = "population"

# %%
obj4.index.name = "state"
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregan         1600.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.index = ["Bob", "Steve", "Jeff", "Ryan"]
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -5
# Ryan     3
# dtype: int64

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada","Nevada", "Nevada"], "year": [2000, 2001, 2002, 2001, 2002, 2003], "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
pd.DataFrame(data, columns=["year", "state", "pop"])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame2 = pd.DataFrame(data, columns=["year", "state", "pop", "debt"])
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2["state"]
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
frame2.loc[1]
# Out:
# year     2001
# state    Ohio
# pop       1.7
# debt      NaN
# Name: 1, dtype: object

# %%
frame2.iloc[2]
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: 2, dtype: object

# %%
frame2["debt"] = 16.5
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5  16.5
# 1  2001    Ohio  1.7  16.5
# 2  2002    Ohio  3.6  16.5
# 3  2001  Nevada  2.4  16.5
# 4  2002  Nevada  2.9  16.5
# 5  2003  Nevada  3.2  16.5

# %%
frame2["debt"] = np.arange(6.)
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   0.0
# 1  2001    Ohio  1.7   1.0
# 2  2002    Ohio  3.6   2.0
# 3  2001  Nevada  2.4   3.0
# 4  2002  Nevada  2.9   4.0
# 5  2003  Nevada  3.2   5.0

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=["two", "four", "five"])
frame2["debt"] = val
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   NaN
# 1  2001    Ohio  1.7   NaN
# 2  2002    Ohio  3.6   NaN
# 3  2001  Nevada  2.4   NaN
# 4  2002  Nevada  2.9   NaN
# 5  2003  Nevada  3.2   NaN

# %%
frame2["eastern"] = frame2["state"] == "Ohio"
frame2
# Out:
#    year   state  pop  debt  eastern
# 0  2000    Ohio  1.5   NaN     True
# 1  2001    Ohio  1.7   NaN     True
# 2  2002    Ohio  3.6   NaN     True
# 3  2001  Nevada  2.4   NaN    False
# 4  2002  Nevada  2.9   NaN    False
# 5  2003  Nevada  3.2   NaN    False

# %%
del frame2["eastern"]

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6}, "Nevada": {2001: 2.4, 2002:2.9}}
populations
# Out:
# {'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}, 'Nevada': {2001: 2.4, 2002: 2.9}}

# %%
frame3 = pd.DataFrame(populations)
frame3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame3.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9

# %%
pd.DataFrame(populations, index=[2001, 2002, 2003])
# Out:
#       Ohio  Nevada
# 2001   1.7     2.4
# 2002   3.6     2.9
# 2003   NaN     NaN

# %%
pdata = {"Ohio": frame3["Ohio"][:-1], "Nevada": frame3["Nevada"][:2]}
pd.DataFrame(pdata)
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4

# %%
frame3.index.name = "year"
frame3.columns.name = "state"
frame3
# Out:
# state  Ohio  Nevada
# year
# 2000    1.5     NaN
# 2001    1.7     2.4
# 2002    3.6     2.9

# %%
frame3.to_numpy()
# Out:
# array([[1.5, nan],
#        [1.7, 2.4],
#        [3.6, 2.9]])

# %%
frame2.to_numpy()
# Out:
# array([[2000, 'Ohio', 1.5, nan],
#        [2001, 'Ohio', 1.7, nan],
#        [2002, 'Ohio', 3.6, nan],
#        [2001, 'Nevada', 2.4, nan],
#        [2002, 'Nevada', 2.9, nan],
#        [2003, 'Nevada', 3.2, nan]], dtype=object)

# %%
obj = pd.Series(np.arange(3), index=["a", "b", "c"])
index = obj.index
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
index[1] = "d"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13833/1597317640.py in <cell line: 0>()
# ----> 1 index[1] = "d"
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5369     @final
#    5370     def __setitem__(self, key, value) -> None:
# -> 5371         raise TypeError("Index does not support mutable operations")
#    5372
#    5373     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
labels = pd.Index(np.arange(3))
labels
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
obj2 = pd.Series([1.5, -2.5, 0], index=labels)
obj2
# Out:
# 0    1.5
# 1   -2.5
# 2    0.0
# dtype: float64

# %%
obj2.index is labels
# Out:
# True

# %%
frame3
# Out:
# state  Ohio  Nevada
# year
# 2000    1.5     NaN
# 2001    1.7     2.4
# 2002    3.6     2.9

# %%
frame3.columns
# Out:
# Index(['Ohio', 'Nevada'], dtype='object', name='state')

# %%
"Ohio" in frame3.columns
# Out:
# True

# %%
2003 in frame3.index
# Out:
# False

# %%
pd.Index(["foo", "foo", "bar", "bar"])
# Out:
# Index(['foo', 'foo', 'bar', 'bar'], dtype='object')
